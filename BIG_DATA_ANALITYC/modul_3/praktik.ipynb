# %%
print("Hello Kris")
x = 17
print("Nilai a = ", x)
# Out:
# Hello Kris
# Nilai a =  17

# %%
print('Hi... How are you')
print('My name is \
Kris')
# Out:
# Hi... How are you
# My name is Kris

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

# %%
plt.axis([0,10,0,25])
# Out:
# (0.0, 10.0, 0.0, 25.0)

# %%
plt.plot([2, 2.5, 6, 7, 9],[4, 11, 14, 17, 24], "gs")
plt.show()

# %%
plt.plot([2, 2.5, 6, 7, 9],[4, 11, 14, 17, 24])
plt.show()

# %%
plt.plot([2, 3, 4, 5],[4, 11, 14, 17])
plt.xlabel("Actual birth weight")
plt.ylabel("Extimate birth weight")
plt.show()

# %%
dataset = pd.read_csv("praktik3.2.csv")
dataset.keys()
# Out:
# Index(['Nilain uts', 'Nilai uas', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
pd.plotting.register_matplotlib_converters()
import seaborn as sns

# %%
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#     age     sex     bmi  children smoker      region       charges
# 0  33.0  female  27.900       0.0    yes  soulthwest   11123.33332
# 1  23.0    male  28.900       1.0     no   northwest    2223.44333
# 2  43.0    male  26.200       2.0     no   northwest  981123.33332
# 3  22.0    male  22.707       1.0     no  soulthwest    2323.44333
# 4  33.0    male  29.800       0.0     no  soulthwest   11123.33332

# %%
sns.scatterplot(x=data['bmi'], y=data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=data['bmi'], y=data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=data['bmi'], y=data['charges'], hue=data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x='bmi', y='charges', data = data)
